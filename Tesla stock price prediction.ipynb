# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import plot

#for offline plotting
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.18.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
tesla = pd.read_csv('tesla.csv')
tesla.head()
# Out:
#          Date       Open   High        Low      Close  Adj Close    Volume
# 0  29-06-2010  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1  30-06-2010  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2  01-07-2010  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3  02-07-2010  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4  06-07-2010  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2193 entries, 0 to 2192
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2193 non-null   object
#  1   Open       2193 non-null   float64
#  2   High       2193 non-null   float64
#  3   Low        2193 non-null   float64
#  4   Close      2193 non-null   float64
#  5   Adj Close  2193 non-null   float64
#  6   Volume     2193 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 120.1+ KB

# %%
tesla['Date']
# Out:
# 0       29-06-2010
# 1       30-06-2010
# 2       01-07-2010
# 3       02-07-2010
# 4       06-07-2010
#            ...
# 2188    11-03-2019
# 2189    12-03-2019
# 2190    13-03-2019
# 2191    14-03-2019
# 2192    15-03-2019
# Name: Date, Length: 2193, dtype: object

# %%
#  tesla['Date'] = tesla['Date'].dt.strftime('%d/%m/%Y')
# tesla['Date'] = tesla['Date'].dt.strftime('%Y-%m-%d')
tesla.style.format({"Date": lambda t: t.strftime("%Y-%m-%d")})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\formatters.py:342, in BaseFormatter.__call__(self, obj)
#     340     method = get_real_method(obj, self.print_method)
#     341     if method is not None:
# --> 342         return method()
#     343     return None
#     344 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\style.py:379, in Styler._repr_html_(self)
#     374 """
#     375 Hooks into Jupyter notebook rich display system, which calls _repr_html_ by
#     376 default if an object is returned at the end of a cell.
#     377 """
#     378 if get_option("styler.render.repr") == "html":
# --> 379     return self.to_html()
#     380 return None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\style.py:1371, in Styler.to_html(self, buf, table_uuid, table_attributes, sparse_index, sparse_columns, bold_headers, caption, max_rows, max_columns, encoding, doctype_html, exclude_styles, **kwargs)
#    1368     obj.set_caption(caption)
#    1370 # Build HTML string..
# -> 1371 html = obj._render_html(
#    1372     sparse_index=sparse_index,
#    1373     sparse_columns=sparse_columns,
#    1374     max_rows=max_rows,
#    1375     max_cols=max_columns,
#    1376     exclude_styles=exclude_styles,
#    1377     encoding=encoding or get_option("styler.render.encoding"),
#    1378     doctype_html=doctype_html,
#    1379     **kwargs,
#    1380 )
#    1382 return save_to_buffer(
#    1383     html, buf=buf, encoding=(encoding if buf is not None else None)
#    1384 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\style_render.py:199, in StylerRenderer._render_html(self, sparse_index, sparse_columns, max_rows, max_cols, **kwargs)
#     187 def _render_html(
#     188     self,
#     189     sparse_index: bool,
#    (...)
#     193     **kwargs,
#     194 ) -> str:
#     195     """
#     196     Renders the ``Styler`` including all applied styles to HTML.
#     197     Generates a dict with necessary kwargs passed to jinja2 template.
#     198     """
# --> 199     d = self._render(sparse_index, sparse_columns, max_rows, max_cols, "&nbsp;")
#     200     d.update(kwargs)
#     201     return self.template_html.render(
#     202         **d,
#     203         html_table_tpl=self.template_html_table,
#     204         html_style_tpl=self.template_html_style,
#     205     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\style_render.py:184, in StylerRenderer._render(self, sparse_index, sparse_columns, max_rows, max_cols, blank)
#     181     for (r, c), v in self.concatenated.ctx_index.items():
#     182         self.ctx_index[(r + len(self.index), c)] = v
# --> 184 d = self._translate(sparse_index, sparse_columns, max_rows, max_cols, blank, dx)
#     185 return d
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\style_render.py:328, in StylerRenderer._translate(self, sparse_index, sparse_cols, max_rows, max_cols, blank, dx)
#     322 self.cellstyle_map: DefaultDict[tuple[CSSPair, ...], list[str]] = defaultdict(
#     323     list
#     324 )
#     325 self.cellstyle_map_index: DefaultDict[
#     326     tuple[CSSPair, ...], list[str]
#     327 ] = defaultdict(list)
# --> 328 body: list = self._translate_body(idx_lengths, max_rows, max_cols)
#     329 d.update({"body": body})
#     331 ctx_maps = {
#     332     "cellstyle": "cellstyle_map",
#     333     "cellstyle_index": "cellstyle_map_index",
#     334     "cellstyle_columns": "cellstyle_map_columns",
#     335 }  # add the cell_ids styles map to the render dictionary in right format
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\style_render.py:616, in StylerRenderer._translate_body(self, idx_lengths, max_rows, max_cols)
#     608     if self._check_trim(
#     609         visible_row_count,
#     610         max_rows,
#     611         body,
#     612         "row",
#     613     ):
#     614         break
# --> 616     body_row = self._generate_body_row(
#     617         (r, row_tup, rlabels), max_cols, idx_lengths
#     618     )
#     619     body.append(body_row)
#     620 return body
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\formats\style_render.py:813, in StylerRenderer._generate_body_row(self, iter, max_cols, idx_lengths)
#     801 if (r, c) in self.cell_context:
#     802     cls = " " + self.cell_context[r, c]
#     804 data_element = _element(
#     805     "td",
#     806     (
#     807         f"{self.css['data']} {self.css['row']}{r} "
#     808         f"{self.css['col']}{c}{cls}"
#     809     ),
#     810     value,
#     811     data_element_visible,
#     812     attributes="",
# --> 813     display_value=self._display_funcs[(r, c)](value),
#     814 )
#     816 if self.cell_ids:
#     817     data_element["id"] = f"{self.css['row']}{r}_{self.css['col']}{c}"
#
# Cell In[15], line 3, in <lambda>(t)
#       1 #  tesla['Date'] = tesla['Date'].dt.strftime('%d/%m/%Y')
#       2 # tesla['Date'] = tesla['Date'].dt.strftime('%Y-%m-%d')
# ----> 3 tesla.style.format({"Date": lambda t: t.strftime("%Y-%m-%d")})
#
# AttributeError: 'str' object has no attribute 'strftime'

# %%
tesla.head()
# Out:
#         Date       Open   High        Low      Close  Adj Close    Volume
# 0 2010-06-29  19.000000  25.00  17.540001  23.889999  23.889999  18766300
# 1 2010-06-30  25.790001  30.42  23.299999  23.830000  23.830000  17187100
# 2 2010-01-07  25.000000  25.92  20.270000  21.959999  21.959999   8218800
# 3 2010-02-07  23.000000  23.10  18.709999  19.200001  19.200001   5139800
# 4 2010-06-07  20.000000  20.00  15.830000  16.110001  16.110001   6866900

# %%
tesla['Date'] = pd.to_datetime(tesla['Date'])

# %%
print(f'Dataframe contains stock prices between {tesla.Date.min()} {tesla.Date.max()}') 
print(f'Total days = {(tesla.Date.max()  - tesla.Date.min()).days} days')
# Out:
# Dataframe contains stock prices between 2010-01-07 00:00:00 2019-12-03 00:00:00
# Total days = 3617 days

# %%
tesla.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2193.000000  2193.000000  2193.000000  2193.000000  2193.000000
# mean    175.652882   178.710262   172.412075   175.648555   175.648555
# std     115.580903   117.370092   113.654794   115.580771   115.580771
# min      16.139999    16.629999    14.980000    15.800000    15.800000
# 25%      33.110001    33.910000    32.459999    33.160000    33.160000
# 50%     204.990005   208.160004   201.669998   204.990005   204.990005
# 75%     262.000000   265.329987   256.209991   261.739990   261.739990
# max     386.690002   389.609985   379.350006   385.000000   385.000000
#
#              Volume
# count  2.193000e+03
# mean   5.077449e+06
# std    4.545398e+06
# min    1.185000e+05
# 25%    1.577800e+06
# 50%    4.171700e+06
# 75%    6.885600e+06
# max    3.716390e+07

# %%
tesla[['Open','High','Low','Close','Adj Close']].plot(kind='box')
# Out:
# <AxesSubplot: >

# %%
# Setting the layout for our plot
layout = go.Layout(
    title='Stock Prices of Tesla',
    xaxis=dict(
        title='Date',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    ),
    yaxis=dict(
        title='Price',
        titlefont=dict(
            family='Courier New, monospace',
            size=18,
            color='#7f7f7f'
        )
    )
)

tesla_data = [{'x':tesla['Date'], 'y':tesla['Close']}]
plot = go.Figure(data=tesla_data, layout=layout)

# %%
#plot(plot) #plotting offline
iplot(plot)
# Out:
# <div>                            <div id="5fc27f5f-f554-4f08-b086-69972cb88f1f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fc27f5f-f554-4f08-b086-69972cb88f1f")) {                    Plotly.newPlot(                        "5fc27f5f-f554-4f08-b086-69972cb88f1f",                        [{"x":["2010-06-29T00:00:00","2010-06-30T00:00:00","2010-07-01T00:00:00","2010-07-02T00:00:00","2010-07-06T00:00:00","2010-07-07T00:00:00","2010-07-08T00:00:00","2010-07-09T00:00:00","2010-07-12T00:00:00","2010-07-13T00:00:00","2010-07-14T00:00:00","2010-07-15T00:00:00","2010-07-16T00:00:00","2010-07-19T00:00:00","2010-07-20T00:00:00","2010-07-21T00:00:00","2010-07-22T00:00:00","2010-07-23T00:00:00","2010-07-26T00:00:00","2010-07-27T00:00:00","2010-07-28T00:00:00","2010-07-29T00:00:00","2010-07-30T00:00:00","2010-08-02T00:00:00","2010-08-03T00:00:00","2010-08-04T00:00:00","2010-08-05T00:00:00","2010-08-06T00:00:00","2010-08-09T00:00:00","2010-08-10T00:00:00","2010-08-11T00:00:00","2010-08-12T00:00:00","2010-08-13T00:00:00","2010-08-16T00:00:00","2010-08-17T00:00:00","2010-08-18T00:00:00","2010-08-19T00:00:00","2010-08-20T00:00:00","2010-08-23T00:00:00","2010-08-24T00:00:00","2010-08-25T00:00:00","2010-08-26T00:00:00","2010-08-27T00:00:00","2010-08-30T00:00:00","2010-08-31T00:00:00","2010-09-01T00:00:00","2010-09-02T00:00:00","2010-09-03T00:00:00","2010-09-07T00:00:00","2010-09-08T00:00:00","2010-09-09T00:00:00","2010-09-10T00:00:00","2010-09-13T00:00:00","2010-09-14T00:00:00","2010-09-15T00:00:00","2010-09-16T00:00:00","2010-09-17T00:00:00","2010-09-20T00:00:00","2010-09-21T00:00:00","2010-09-22T00:00:00","2010-09-23T00:00:00","2010-09-24T00:00:00","2010-09-27T00:00:00","2010-09-28T00:00:00","2010-09-29T00:00:00","2010-09-30T00:00:00","2010-10-01T00:00:00","2010-10-04T00:00:00","2010-10-05T00:00:00","2010-10-06T00:00:00","2010-10-07T00:00:00","2010-10-08T00:00:00","2010-10-11T00:00:00","2010-10-12T00:00:00","2010-10-13T00:00:00","2010-10-14T00:00:00","2010-10-15T00:00:00","2010-10-18T00:00:00","2010-10-19T00:00:00","2010-10-20T00:00:00","2010-10-21T00:00:00","2010-10-22T00:00:00","2010-10-25T00:00:00","2010-10-26T00:00:00","2010-10-27T00:00:00","2010-10-28T00:00:00","2010-10-29T00:00:00","2010-11-01T00:00:00","2010-11-02T00:00:00","2010-11-03T00:00:00","2010-11-04T00:00:00","2010-11-05T00:00:00","2010-11-08T00:00:00","2010-11-09T00:00:00","2010-11-10T00:00:00","2010-11-11T00:00:00","2010-11-12T00:00:00","2010-11-15T00:00:00","2010-11-16T00:00:00","2010-11-17T00:00:00","2010-11-18T00:00:00","2010-11-19T00:00:00","2010-11-22T00:00:00","2010-11-23T00:00:00","2010-11-24T00:00:00","2010-11-26T00:00:00","2010-11-29T00:00:00","2010-11-30T00:00:00","2010-12-01T00:00:00","2010-12-02T00:00:00","2010-12-03T00:00:00","2010-12-06T00:00:00","2010-12-07T00:00:00","2010-12-08T00:00:00","2010-12-09T00:00:00","2010-12-10T00:00:00","2010-12-13T00:00:00","2010-12-14T00:00:00","2010-12-15T00:00:00","2010-12-16T00:00:00","2010-12-17T00:00:00","2010-12-20T00:00:00","2010-12-21T00:00:00","2010-12-22T00:00:00","2010-12-23T00:00:00","2010-12-27T00:00:00","2010-12-28T00:00:00","2010-12-29T00:00:00","2010-12-30T00:00:00","2010-12-31T00:00:00","2011-01-03T00:00:00","2011-01-04T00:00:00","2011-01-05T00:00:00","2011-01-06T00:00:00","2011-01-07T00:00:00","2011-01-10T00:00:00","2011-01-11T00:00:00","2011-01-12T00:00:00","2011-01-13T00:00:00","2011-01-14T00:00:00","2011-01-18T00:00:00","2011-01-19T00:00:00","2011-01-20T00:00:00","2011-01-21T00:00:00","2011-01-24T00:00:00","2011-01-25T00:00:00","2011-01-26T00:00:00","2011-01-27T00:00:00","2011-01-28T00:00:00","2011-01-31T00:00:00","2011-02-01T00:00:00","2011-02-02T00:00:00","2011-02-03T00:00:00","2011-02-04T00:00:00","2011-02-07T00:00:00","2011-02-08T00:00:00","2011-02-09T00:00:00","2011-02- ...

# %%
# Building the regression model
from sklearn.model_selection import train_test_split

#For preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

#For model evaluation
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

# %%
#Split the data into train and test sets
X = np.array(tesla.index).reshape(-1,1)
Y = tesla['Close']
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=101)

# %%
# Feature scaling
scaler = StandardScaler().fit(X_train)

# %%
from sklearn.linear_model import LinearRegression

# %%
#Creating a linear model
lm = LinearRegression()
lm.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
#Plot actual and predicted values for train dataset
trace0 = go.Scatter(
    x = X_train.T[0],
    y = Y_train,
    mode = 'markers',
    name = 'Actual'
)
trace1 = go.Scatter(
    x = X_train.T[0],
    y = lm.predict(X_train).T,
    mode = 'lines',
    name = 'Predicted'
)
tesla_data = [trace0,trace1]
layout.xaxis.title.text = 'Day'
plot2 = go.Figure(data=tesla_data, layout=layout)

# %%
iplot(plot2)
# Out:
# <div>                            <div id="fa210e56-0ec1-4f1e-8bb0-daf3f1d997f6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa210e56-0ec1-4f1e-8bb0-daf3f1d997f6")) {                    Plotly.newPlot(                        "fa210e56-0ec1-4f1e-8bb0-daf3f1d997f6",                        [{"mode":"markers","name":"Actual","x":[365,1111,1581,1990,1753,1357,135,1851,123,677,1946,525,414,2114,2173,1115,719,986,1403,2001,68,182,70,737,1180,1614,1526,292,280,1145,1613,800,1600,171,790,1185,1726,1027,920,1457,260,1261,1597,119,552,576,1227,1579,217,2023,383,704,5,933,149,1841,587,1809,2103,2010,84,1390,1589,1644,941,2080,544,1546,1